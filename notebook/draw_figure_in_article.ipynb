# %%
import sys
sys.path.append(r'../script/')
from draw_figure_in_article import *

# %% [markdown]
# ### Figure 1:The mass distribution of each AA in per unit mass of different proteins

# %%
fig_file = '../analysis_result/article_figures'
isFileExists(fig_file)

strain_list = ['Corynebacterium_RNA_seq','MG1655','Bacillus','Yeast_single_cell']
strainName = ['C. glutamicum','E. coli','B. subtilis', 'S. cerevisiae']
analysis_result =  '../analysis_result/initial_data'

AAs_Mass_ratio_in_different_species(fig_file,strain_list,strainName,analysis_result)

# %% [markdown]
# ### Figure 2:The mass ratio distribution of different proteins in per unit mass of total protein (only the pro-teins with a mean mass ratio among the top 50 are displayed)

# %%
fig_file = '../analysis_result/article_figures'
strain_list = ['Corynebacterium_RNA_seq','MG1655','Bacillus','Yeast_single_cell']
strainName = ['C. glutamicum','E. coli','B. subtilis', 'S. cerevisiae']
analysis_result =  '../analysis_result/initial_data'

Total_mass_ratio_top(fig_file,strain_list,strainName,analysis_result)
# Out:
# /home/wu_k/anaconda3/envs/AAComics/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/wu_k/anaconda3/envs/AAComics/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/wu_k/anaconda3/envs/AAComics/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
# ...

# %% [markdown]
# ### Figure 3:The mass distribution of each AA per unit mass of total protein

# %%
fig_file = '../analysis_result/article_figures'
strain_list = ['BW25113','DH1','MG1655','W3110']
strainName = ['BW25113','DH1','MG1655','W3110']
analysis_result =  '../analysis_result/initial_data'

AAs_mass_distribution_total_protein(fig_file,strain_list,strainName,analysis_result)
# Out:
# /home/wu_k/anaconda3/envs/AAComics/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/wu_k/anaconda3/envs/AAComics/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/wu_k/anaconda3/envs/AAComics/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
# ...

# %% [markdown]
# ### Figure 4:Distribution of the mass ratio of twenty AAs per unit mass of total protein in different species

# %%
fig_file = '../analysis_result/article_figures'
strain_list = ['Corynebacterium_RNA_seq','MG1655','Bacillus','Yeast_single_cell']
strainName = ['C. glutamicum','E. coli','B. subtilis', 'S. cerevisiae']
analysis_result =  '../analysis_result/initial_data'

AAs_mass_distribution_total_protein(fig_file,strain_list,strainName,analysis_result)
# Out:
# /home/wu_k/anaconda3/envs/AAComics/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/wu_k/anaconda3/envs/AAComics/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# /home/wu_k/anaconda3/envs/AAComics/lib/python3.11/site-packages/numpy/core/fromnumeric.py:3430: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
# ...

# %% [markdown]
# ### Figure S1:Distribution of the molecular weight of proteins in E. coli, B. subtilis, S. cerevisiae, and C. glutamicum

# %%
fig_file = '../analysis_result/article_figures'
strain_list = ['Corynebacterium_RNA_seq','MG1655','Bacillus','Yeast_single_cell']
strainName = ['C. glutamicum','E. coli','B. subtilis', 'S. cerevisiae']
analysis_result =  '../analysis_result/initial_data'

Comparison_of_protein_MW_by_species(strain_list,strainName,fig_file,analysis_result)
# Out:
# mw_stat_std:
#                     mean         sd   sd/mean
# C. glutamicum  33.717116  23.846724  0.707259
# E. coli        35.552135  22.821792  0.641925
# B. subtilis    32.981638  29.696616  0.900398
# S. cerevisiae  54.551050  41.838207  0.766955
